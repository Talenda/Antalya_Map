# %%
#Visualization
import webbrowser
#webbrowser.open('https://python-visualization.github.io/folium/quickstart.html')

# %%
#Leaflet document
import webbrowser
#webbrowser.open ('https://www.earthdatascience.org/tutorials/introduction-to-leaflet-animated-maps/')

# %%
# DateOffsets
import webbrowser
#webbrowser.open('https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects')

# %%
# Datetime python document
import webbrowser
#webbrowser.open('https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior')

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# _Ekte iki adet excel gonderiyorum. Bu dosyalardan birinde (Akım diyelim) Antalya havzasında bulunan akım gözlem istasyonlarına ait günlük akım değerleri var (2000-2015 yılları için). Digerinde istasyonlara ait koordinatlar (koordinat diyelim) var. Soyle bir kod yazarsan iyi bir pratik olur:_
#
# **flw for Akım**
#
# **cor for kordinat**

# %%
cor = pd.read_excel('FlowBook_Antalya_Basin_2015_Station_Info.xlsx')
flw = pd.read_excel('EFAS_3_5_Dis24_TimeSeries_Basin_Antalya_2000_2015.xlsx')

# %%
flw.shape
# Out:
# (5844, 23)

# %%
cor.shape
# Out:
# (46, 6)

# %%
flw.head(3)
# Out:
#    Unnamed: 0    Historical_times   D09A011   D09A031   D09A034   D09A057  \
# 0           0 2000-01-01 06:00:00  0.935547  2.056641  0.683594  0.316406
# 1           1 2000-01-02 06:00:00  0.832031  1.769531  0.637695  0.314453
# 2           2 2000-01-03 06:00:00  0.807617  1.626953  0.642578  0.320312
#
#     D09A065   D09A067   D09A068   D09A086  ...   D09A100   D09A101   D09A122  \
# 0  0.156250  5.136719  5.797852  1.664062  ...  0.962891  8.919922  1.004883
# 1  0.158203  4.430664  5.011719  1.497070  ...  0.840820  8.386719  0.875000
# 2  0.158203  3.958984  4.508789  1.385742  ...  0.792969  7.865234  0.833008
#
#     E09A002    E09A012    E09A017   E09A021    E09A022    E09A024   E09A099
# 0  6.404297  24.528320  21.681641  3.103516  11.973633  17.578125  5.196289
# 1  6.090820  21.171875  19.059570  2.833008  10.519531  15.412109  4.870117
# 2  5.793945  19.541992  16.958008  2.600586   9.642578  13.960938  4.669922
#
# [3 rows x 23 columns]

# %%
cor.head(3)
# Out:
#    id   stname   area  elev       east      north
# 0   0  D09A002   61.7  1250  31.091111  37.811667
# 1   1  D09A006  195.0    38  32.121667  36.549444
# 2   2  D09A011  130.7  1190  30.050000  37.133333

# %%
flw.describe()
# Out:
#         Unnamed: 0      D09A011      D09A031      D09A034      D09A057  \
# count  5844.000000  5844.000000  5844.000000  5844.000000  5844.000000
# mean   2921.500000     2.065230     8.701641     3.782037     1.244513
# std    1687.161818     3.318011    16.604812     6.443618     1.659987
# min       0.000000     0.070312     0.031738     0.049316     0.005371
# 25%    1460.750000     0.372070     1.113647     0.742065     0.436035
# 50%    2921.500000     0.703613     2.235596     1.309326     0.692139
# 75%    4382.250000     2.267517     8.215942     3.672729     1.265137
# max    5843.000000    59.634521   258.875244    70.223145    23.359863
#
#            D09A065      D09A067      D09A068      D09A086      D09A089  ...  \
# count  5844.000000  5844.000000  5844.000000  5844.000000  5844.000000  ...
# mean      0.609238     6.861581     8.072068     4.634996     5.872580  ...
# std       0.786046     9.750471    12.595158     5.803809     8.284670  ...
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# _1) Akım dosyasındaki butun istasyon numaralarını okut (ornegin D09A011 ...), sonra bu okuttugun istasyonlar icin koordinat dosyasindan koordinatlarini (East ve north), alanını ve elevation bilgilerini bir dataframe e yazdir._

# %%
flw.columns
# Out:
# Index(['Unnamed: 0', 'Historical_times', 'D09A011', 'D09A031', 'D09A034',
#        'D09A057', 'D09A065', 'D09A067', 'D09A068', 'D09A086', 'D09A089',
#        'D09A091', 'D09A095', 'D09A100', 'D09A101', 'D09A122', 'E09A002',
#        'E09A012', 'E09A017', 'E09A021', 'E09A022', 'E09A024', 'E09A099'],
#       dtype='object')

# %% [markdown]
# *To see all column names in flw*

# %%
flw.columns[2:]
# Out:
# Index(['D09A011', 'D09A031', 'D09A034', 'D09A057', 'D09A065', 'D09A067',
#        'D09A068', 'D09A086', 'D09A089', 'D09A091', 'D09A095', 'D09A100',
#        'D09A101', 'D09A122', 'E09A002', 'E09A012', 'E09A017', 'E09A021',
#        'E09A022', 'E09A024', 'E09A099'],
#       dtype='object')

# %% [markdown]
# *index(0,1) are not station names so I exclude them*

# %%
lis=list(flw.columns.values[2:])

# %%
len(lis)
# Out:
# 21

# %% [markdown]
# *list which contains all stations in flw*

# %%
cor['stname'].isin(lis).head(8)
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6     True
# 7    False
# Name: stname, dtype: bool

# %% [markdown]
# *boolean series which shows all included station names as True others as False*

# %%
filt=cor['stname'].isin(lis)

# %%
cor[filt]
# Out:
#     id   stname     area  elev       east      north
# 2    2  D09A011   130.70  1190  30.050000  37.133333
# 5    5  D09A031   404.60    52  30.573611  36.934722
# 6    6  D09A034   238.60    62  30.942222  37.131667
# 10  10  D09A057   185.00   950  30.954722  38.299444
# 12  12  D09A065   103.48  1198  31.126944  38.394167
# 13  13  D09A067   303.20   100  31.622778  36.743889
# 14  14  D09A068   336.32    16  31.800000  36.613889
# 17  17  D09A086   349.00  1000  31.123611  37.623056
# 19  19  D09A089   313.90   320  30.912222  37.462778
# 20  20  D09A091  2000.00   300  30.580556  37.071944
# 21  21  D09A095   164.00   160  30.467222  36.825000
# 23  23  D09A100   223.00  1085  31.155556  37.659167
# 24  24  D09A101  2330.00    20  31.199722  36.980000
# 28  28  D09A122   144.84    80  31.284722  36.991667
# 34  34  E09A002  1942.40   116  31.188611  37.141667
# 35  35  E09A012   625.60   245  31.608611  36.979444
# 36  36  E09A017   875.50    28  31.726667  36.696944
# ...

# %% [markdown]
# *Boolean series named as filt and used to filter dataframe to show needed stations*

# %%
que1 =cor[filt]

# %%
que1.stname.count()
# Out:
# 20

# %% [markdown]
# *que1 is a dataframe which contains answer of question1*

# %%
que1
# Out:
#     id   stname     area  elev       east      north
# 2    2  D09A011   130.70  1190  30.050000  37.133333
# 5    5  D09A031   404.60    52  30.573611  36.934722
# 6    6  D09A034   238.60    62  30.942222  37.131667
# 10  10  D09A057   185.00   950  30.954722  38.299444
# 12  12  D09A065   103.48  1198  31.126944  38.394167
# 13  13  D09A067   303.20   100  31.622778  36.743889
# 14  14  D09A068   336.32    16  31.800000  36.613889
# 17  17  D09A086   349.00  1000  31.123611  37.623056
# 19  19  D09A089   313.90   320  30.912222  37.462778
# 20  20  D09A091  2000.00   300  30.580556  37.071944
# 21  21  D09A095   164.00   160  30.467222  36.825000
# 23  23  D09A100   223.00  1085  31.155556  37.659167
# 24  24  D09A101  2330.00    20  31.199722  36.980000
# 28  28  D09A122   144.84    80  31.284722  36.991667
# 34  34  E09A002  1942.40   116  31.188611  37.141667
# 35  35  E09A012   625.60   245  31.608611  36.979444
# 36  36  E09A017   875.50    28  31.726667  36.696944
# ...

# %% [markdown]
# que1.to_excel('Question_1.xlsx')

# %% [markdown]
# _making excel file for question1_

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# *2) leaflet ile Turkiye haritasi sekli olustur ve bu Turkiye haritasina koordinatlari kullanarak akim gozlem istasyonlarının yerlerine bir marker koy. MArker uzerinde ise istasyon numarasi label i olsun. Marker altinda ise istasyon alani ve elevation bilgileri olsun.*

# %%
#conda install -c conda-forge folium

# %% [markdown]
# _To upload Folium_

# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd

# %%
#Define coordinates of where we want to center our map
boulder_coords = [36.884804, 30.704044]

# %%
my_map = folium.Map(location = boulder_coords, zoom_start = 8,control_scale=True)

# %%
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
east = que1.east
north = que1.north
name = que1.stname
elevation = que1.elev
area = que1.area

# %% [markdown]
# _Series contain needed variables_

# %%
east.head(3)
# Out:
# 2    30.050000
# 5    30.573611
# 6    30.942222
# Name: east, dtype: float64

# %%
east.shape
# Out:
# (20,)

# %%
east[0:1]
# Out:
# 2    30.05
# Name: east, dtype: float64

# %%
north.iloc[0]
# Out:
# 37.13333333333333

# %%
east.iloc[0]
# Out:
# 30.05

# %% [markdown]
# station_coords = [north.iloc[1], east.iloc[1]]
# folium.Marker(station_coords, popup = name.iloc[1]).add_to(my_map)

# %% [markdown]
# for i in range(que1.stname.count()):
#     station_coords = [north.iloc[i], east.iloc[i]]
#     folium.Marker(station_coords, popup = ['Station Name:',name.iloc[i], '\t Elevation:',elevation.iloc[i], '\t Area:', area.iloc[i]] ).add_to(my_map)

# %% [markdown]
# my_map

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# _3)EFAS excel dosyasinda her istasyon icin 2000-2015 yillari arasinda gunluk akim veriler var. Bu akim verilerinde sifir veya sifidan buyuk degerleri her ay icin ortalamasini alabilirsin. Ornegin 16 adet ocak ayinin ortalamasi. Boylece her istasyon icin 12 deger olacak - her aydaki ortalama. Bu degerleri bar chart olarak grafigini cizdirelim. Ve leaflet haritasi uzerinde bir istasyona tikladigimizda ilgili bar chart gorunsun._

# %%
# DateOffsets
import webbrowser
#webbrowser.open('https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects')

# %%
# Datetime python document
import webbrowser
#webbrowser.open('https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior')

# %%
#Visualization
import webbrowser
#webbrowser.open('https://python-visualization.github.io/folium/quickstart.html')

# %%
# some solutions
import webbrowser
#webbrowser.open('https://stackoverflow.com/questions/49582831/adding-jpg-images-to-folium-popup')

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# _notes about above column/columns given as italic like this, hided codes are just markdowns_

# %%
flw.dtypes.Historical_times
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# _I check the flw data Historical_times columns if it is datetime or not dtype('<M8[ns]') means datetime64 so no need for version ( if it was object or smthg i need to convert it to work with it as data)_

# %%
flw.loc[0,'Historical_times'].day_name()
# Out:
# 'Saturday'

# %% [markdown]
# _datetime methods works this also show its format is datetime_

# %%
flw.set_index('Historical_times', inplace=True)

# %%
flw
# Out:
#                      Unnamed: 0   D09A011   D09A031   D09A034   D09A057  \
# Historical_times
# 2000-01-01 06:00:00           0  0.935547  2.056641  0.683594  0.316406
# 2000-01-02 06:00:00           1  0.832031  1.769531  0.637695  0.314453
# 2000-01-03 06:00:00           2  0.807617  1.626953  0.642578  0.320312
# 2000-01-04 06:00:00           3  0.734375  1.634766  0.658203  0.318359
# 2000-01-05 06:00:00           4  0.637695  1.666992  0.660156  0.313477
# ...                         ...       ...       ...       ...       ...
# 2015-12-27 06:00:00        5839  0.344238  1.526367  0.770508  0.348633
# 2015-12-28 06:00:00        5840  0.340820  1.505371  0.762695  0.345703
# 2015-12-29 06:00:00        5841  0.337402  1.488281  0.755371  0.342285
# 2015-12-30 06:00:00        5842  0.333984  1.471680  0.747559  0.339355
# 2015-12-31 06:00:00        5843  0.330566  1.455566  0.740234  0.335938
#
#                       D09A065   D09A067   D09A068   D09A086   D09A089  ...  \
# ...

# %% [markdown]
# _I set index as Historical_times to work with easily_

# %%
flw_month =flw.resample('M').mean()

# %% [markdown]
# _'M' shows calender month as end of year but it takes mean of all values in that month_

# %%
flw_month
# Out:
#                   Unnamed: 0   D09A011   D09A031   D09A034   D09A057  \
# Historical_times
# 2000-01-31              15.0  0.446730  2.303805  0.867361  0.222010
# 2000-02-29              45.0  2.642662  3.974239  1.640979  1.658489
# 2000-03-31              75.0  2.678553  4.926884  2.033518  2.115801
# 2000-04-30             105.5  2.326042  5.757715  2.920443  1.261751
# 2000-05-31             136.0  1.564469  6.160345  2.963206  1.227319
# ...                      ...       ...       ...       ...       ...
# 2015-08-31            5706.0  0.420237  1.221113  0.960016  1.032644
# 2015-09-30            5736.5  0.825033  2.787126  1.095199  0.791895
# 2015-10-31            5767.0  0.935689  5.361407  1.347814  0.660834
# 2015-11-30            5797.5  0.588509  2.858333  1.032308  0.501953
# 2015-12-31            5828.0  0.407132  2.256127  0.931735  0.389428
#
#                    D09A065    D09A067    D09A068   D09A086   D09A089  ...  \
# ...

# %%
flw_month.drop(['Unnamed: 0'], axis=1, inplace=True)

# %% [markdown]
# _I dropped Unnamed: 0 column from flw_month, it is not a station_

# %%
flw_month.shape
# Out:
# (192, 21)

# %%
flw_month[flw_month.index.month.isin([1])]
# Out:
#                    D09A011    D09A031    D09A034   D09A057   D09A065  \
# Historical_times
# 2000-01-31        0.446730   2.303805   0.867361  0.222010  0.058468
# 2001-01-31        6.067887  29.018791  11.788464  1.225964  0.288905
# 2002-01-31        5.264018  22.969396  11.796954  3.268460  1.498960
# 2003-01-31        8.698667  44.200258  16.875693  1.179262  0.407227
# 2004-01-31        9.711780  59.973554  24.576511  5.669930  1.721995
# 2005-01-31        3.765011  44.101295  16.401036  1.262648  0.226972
# 2006-01-31        2.701282  25.463568   8.066737  0.357201  0.173781
# 2007-01-31        2.484414  13.907927   5.866746  1.489841  0.884403
# 2008-01-31        0.623882   2.591466   1.095034  0.709402  0.317123
# 2009-01-31        2.051632   4.697833   1.459347  1.848790  0.814154
# 2010-01-31        3.605658  29.968655  11.766350  4.902155  2.410881
# 2011-01-31        1.537361   6.107044   1.936208  1.099893  0.482863
# ...

# %%
flw_month[flw_month.index.month.isin([0])]
# Out:
# Empty DataFrame
# Columns: [D09A011, D09A031, D09A034, D09A057, D09A065, D09A067, D09A068, D09A086, D09A089, D09A091, D09A095, D09A100, D09A101, D09A122, E09A002, E09A012, E09A017, E09A021, E09A022, E09A024, E09A099]
# Index: []
#
# [0 rows x 21 columns]

# %%
flw_month[flw_month.index.month.isin([12])]
# Out:
#                     D09A011    D09A031    D09A034   D09A057   D09A065  \
# Historical_times
# 2000-12-31         2.706921   9.586883   3.582441  0.778604  0.157274
# 2001-12-31        15.669276  83.999394  38.157297  8.205543  2.279147
# 2002-12-31         5.433058  16.299033   4.773894  0.730532  0.219868
# 2003-12-31         7.562791  28.972837  10.846325  3.962859  0.828897
# 2004-12-31         4.195202  12.901288   3.738959  0.364762  0.156597
# 2005-12-31         1.196163   4.074030   1.253875  0.383206  0.199613
# 2006-12-31         0.788275   3.757308   1.785487  0.681956  0.356760
# 2007-12-31         3.733603  13.466718   4.188020  2.954306  1.138562
# 2008-12-31         0.518334   1.279139   0.480768  0.451062  0.213458
# 2009-12-31         9.860336  45.929735  16.887491  3.056814  0.775895
# 2010-12-31         2.586883   7.750914   2.186240  2.504158  0.913684
# 2011-12-31         1.107233   5.972451   1.857776  0.393602  0.217640
# ...

# %% [markdown]
# _Values for first month for each year_

# %%
flw_month[flw_month.index.month.isin([1])].mean()
# Out:
# D09A011      4.158108
# D09A031     26.502700
# D09A034     10.346158
# D09A057      1.952420
# D09A065      0.725195
# D09A067     16.194529
# D09A068     19.678267
# D09A086      6.606587
# D09A089     11.948677
# D09A091    121.568549
# D09A095      9.633979
# D09A100      4.020496
# D09A101     71.332254
# D09A122      6.959766
# E09A002     48.316394
# E09A012     72.391863
# E09A017     39.587157
# E09A021     13.848420
# E09A022     17.762445
# E09A024     27.019159
# E09A099     32.255833
# dtype: float64

# %% [markdown]
# _Mean of the discharge values for first month_

# %%
column_names = ['Jan','Feb','Mar','Apr','May','June','July','Aug','Sept','Oct','Nov','Dec']
char = pd.DataFrame(columns = column_names)

# %%
len(char.columns)
# Out:
# 12

# %% [markdown]
# # Loop for month in empty df

# %%
for i in range(len(column_names)):
    char[column_names[i]] = flw_month[flw_month.index.month.isin([i+1])].mean()

# %% [markdown]
# char['Jan'] = flw_month[flw_month.index.month.isin([1])].mean()

# %% [markdown]
# char['Feb'] = flw_month[flw_month.index.month.isin([2])].mean()

# %% [markdown]
# char['Mar'] = flw_month[flw_month.index.month.isin([3])].mean()

# %% [markdown]
# char['Apr'] = flw_month[flw_month.index.month.isin([4])].mean()

# %% [markdown]
# char['May'] = flw_month[flw_month.index.month.isin([5])].mean()

# %% [markdown]
# char['June'] = flw_month[flw_month.index.month.isin([6])].mean()

# %% [markdown]
# char['July'] = flw_month[flw_month.index.month.isin([7])].mean()

# %% [markdown]
# char['Aug'] = flw_month[flw_month.index.month.isin([8])].mean()

# %% [markdown]
# char['Sept'] = flw_month[flw_month.index.month.isin([9])].mean()

# %% [markdown]
# char['Oct'] = flw_month[flw_month.index.month.isin([10])].mean()

# %% [markdown]
# char['Nov'] = flw_month[flw_month.index.month.isin([11])].mean()

# %% [markdown]
# char['Dec'] = flw_month[flw_month.index.month.isin([12])].mean()

# %% [markdown]
# for i in range(len(char.columns)):
#     char.columns[i]=(flw_month[flw_month.index.month.isin([i])].mean())

# %% [markdown]
# for j in range (len(flw_month.columns)):
#     for i in range(len(char.columns)):
#         chart.columns[j]=(flw_month[flw_month.index.month.isin([i])].mean())

# %%
chart = char.T

# %%
chart.columns
# Out:
# Index(['D09A011', 'D09A031', 'D09A034', 'D09A057', 'D09A065', 'D09A067',
#        'D09A068', 'D09A086', 'D09A089', 'D09A091', 'D09A095', 'D09A100',
#        'D09A101', 'D09A122', 'E09A002', 'E09A012', 'E09A017', 'E09A021',
#        'E09A022', 'E09A024', 'E09A099'],
#       dtype='object')

# %%
chart
# Out:
#        D09A011    D09A031    D09A034   D09A057   D09A065    D09A067  \
# Jan   4.158108  26.502700  10.346158  1.952420  0.725195  16.194529
# Feb   4.570760  19.916097   8.683139  2.318805  1.056361  16.277558
# Mar   3.673366  12.125223   5.714079  2.186758  1.424089  10.182269
# Apr   1.930504   6.436855   3.470537  1.528481  1.151098   7.110412
# May   1.081402   3.790044   2.228365  1.137018  0.637810   3.730913
# June  0.668742   2.163016   1.425980  0.940933  0.512061   1.962390
# July  0.462460   1.440171   1.020296  0.654206  0.340317   1.419829
# Aug   0.349462   0.981396   0.761698  0.478178  0.237015   1.062216
# Sept  0.397498   0.891532   0.625165  0.491478  0.196144   0.984163
# Oct   1.179958   4.120257   1.485702  0.689838  0.228707   2.601970
# Nov   2.146716   7.612463   2.714526  0.849418  0.277221   6.582084
# Dec   4.297297  18.908516   7.139049  1.767102  0.557989  14.718901
#
#         D09A068   D09A086    D09A089     D09A091  ...   D09A100    D09A101  \
# ...

# %%
char['Jan'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of D09A011      4.158108
# D09A031     26.502700
# D09A034     10.346158
# D09A057      1.952420
# D09A065      0.725195
# D09A067     16.194529
# D09A068     19.678267
# D09A086      6.606587
# D09A089     11.948677
# D09A091    121.568549
# D09A095      9.633979
# D09A100      4.020496
# D09A101     71.332254
# D09A122      6.959766
# E09A002     48.316394
# E09A012     72.391863
# E09A017     39.587157
# E09A021     13.848420
# E09A022     17.762445
# E09A024     27.019159
# E09A099     32.255833
# Name: Jan, dtype: float64>

# %% [markdown]
# _Lenght of the char is used as range for i_

# %% [markdown]
# _I created an empty dataframe with columns named as Months and I imported mean values of discharges for corresponded month in it_

# %%
char
# Out:
#                 Jan         Feb        Mar        Apr        May       June  \
# D09A011    4.158108    4.570760   3.673366   1.930504   1.081402   0.668742
# D09A031   26.502700   19.916097  12.125223   6.436855   3.790044   2.163016
# D09A034   10.346158    8.683139   5.714079   3.470537   2.228365   1.425980
# D09A057    1.952420    2.318805   2.186758   1.528481   1.137018   0.940933
# D09A065    0.725195    1.056361   1.424089   1.151098   0.637810   0.512061
# D09A067   16.194529   16.277558  10.182269   7.110412   3.730913   1.962390
# D09A068   19.678267   19.444006  11.264004   7.673698   3.885029   2.050211
# D09A086    6.606587    8.372141   9.552353   8.196057   4.415499   2.849122
# D09A089   11.948677   12.699412   9.841935   7.340286   4.777469   2.931069
# D09A091  121.568549  105.076275  71.477573  47.374292  29.791279  16.222486
# D09A095    9.633979    7.935410   5.863386   4.281067   2.291739   1.079595
# ...

# %% [markdown]
# _char stands for charts and it contains all stations as rows and all mean values of discharges each month between 2000-2015_

# %%
chart = char.T

# %% [markdown]
# _chart stands for Transpose of char_

# %%
ax = chart[name.iloc[6]].plot(kind='bar', figsize=(14,6))
ax.set_ylabel('Mean Discharge')
ax.set_xlabel('Months')
ax.grid(zorder=0)

# %% [markdown]
# _Bar chart for seventh station_

# %%
import json
import requests

# %% [markdown]
# for i in range(que1.stname.count()):
#     station_coords = [north.iloc[i], east.iloc[i]]
#     folium.Marker(station_coords, popup = ['Station Name:',name.iloc[i], '\t Elevation:',elevation.iloc[i], '\t Area:', area.iloc[i]],tooltip= name.iloc[i],icon=folium.Icon(icon="cloud", color ='darkblue')).add_to(my_map)

# %% [markdown]
# my_map.add_child(folium.LatLngPopup())

# %% [markdown]
# _This allows user to shows lat long values by clivking any area on map_

# %%
# some solutions
import webbrowser
#webbrowser.open('https://stackoverflow.com/questions/49582831/adding-jpg-images-to-folium-popup')

# %% [markdown]
# _Save bar chart as png to upload it on coresponding markers_

# %%
marker = folium.Marker(
    location=[north.iloc[0],east.iloc[0]],
    tooltip= name.iloc[0],
    icon=folium.Icon(icon="cloud", color ='darkblue'),
    popup="<b><img src=vis/vis0.png></b>"
)

marker.add_to(my_map)

# %% [markdown]
# _Uploading png's to coresponding markers_

# %% [markdown]
# _This 2 code works for uploading charts on map, I used loops to upload all markers below_

# %%
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
name.shape
# Out:
# (20,)

# %% [markdown]
# _To check how many data I need_

# %% [markdown]
# ### Charts to png

# %%
name.iloc[:].count()
# Out:
# 20

# %% [markdown]
# # Loop for drawing graph

# %% [markdown]
# for i in range(len(north)):
#     ax = chart[name.iloc[i]].plot(kind='bar',figsize=(4,3),zorder=3,color='purple')
#     ax.set_ylabel('Mean Discharge')
#     ax.set_xlabel('Months')
#     ax.grid(zorder=0,linestyle='dotted', color='black')
#     ax.get_figure().savefig(f"vis2/vis{i}.png",bbox_inches='tight')
#     ax.cla()

# %% [markdown]
# _ax.cla clear code after run it for pyplots like histogram chart_

# %% [markdown]
# ax = chart[name.iloc[0]].plot(kind='bar',figsize=(4,3),zorder=3,color='purple')
# ax.set_ylabel('Mean Discharge')
# ax.set_xlabel('Months')
# ax.grid(zorder=0,linestyle='dotted', color='black')
# ax.get_figure().savefig(f"vis/vis{0}.png",bbox_inches='tight')

# %% [markdown]
# ax = chart[name.iloc[1]].plot(kind='bar',figsize=(4,3),zorder=3,color='purple')
# ax.set_ylabel('Mean Discharge')
# ax.set_xlabel('Months')
# ax.grid(zorder=0,linestyle='dotted', color='black')
# ax.get_figure().savefig(f"vis/vis{1}.png",bbox_inches='tight')

# %% [markdown]
# ax = chart[name.iloc[2]].plot(kind='bar',figsize=(4,3),zorder=3,color='purple')
# ax.set_ylabel('Mean Discharge')
# ax.set_xlabel('Months')
# ax.grid(zorder=0,linestyle='dotted', color='black')
# ax.get_figure().savefig(f"vis/vis{2}.png",bbox_inches='tight')

# %% [markdown]
# ax = chart[name.iloc[3]].plot(kind='bar',figsize=(4,3),zorder=3,color='purple')
# ax.set_ylabel('Mean Discharge')
# ax.set_xlabel('Months')
# ax.grid(zorder=0,linestyle='dotted', color='black')
# ax.get_figure().savefig(f"vis/vis{3}.png",bbox_inches='tight')

# %% [markdown]
# ax = chart[name.iloc[4]].plot(kind='bar',figsize=(4,3),zorder=3,color='purple')
# ax.set_ylabel('Mean Discharge')
# ax.set_xlabel('Months')
# ax.grid(zorder=0,linestyle='dotted', color='black')
# ax.get_figure().savefig(f"vis/vis{4}.png",bbox_inches='tight')

# %% [markdown]
# ax = chart[name.iloc[5]].plot(kind='bar',figsize=(4,3),zorder=3,color='purple')
# ax.set_ylabel('Mean Discharge')
# ax.set_xlabel('Months')
# ax.grid(zorder=0,linestyle='dotted', color='black')
# ax.get_figure().savefig(f"vis/vis{5}.png",bbox_inches='tight')

# %% [markdown]
# ax = chart[name.iloc[6]].plot(kind='bar',figsize=(4,3),zorder=3,color='purple')
# ax.set_ylabel('Mean Discharge')
# ax.set_xlabel('Months')
# ax.grid(zorder=0,linestyle='dotted', color='black')
# ax.get_figure().savefig(f"vis/vis{6}.png",bbox_inches='tight')

# %% [markdown]
# ax = chart[name.iloc[7]].plot(kind='bar',figsize=(4,3),zorder=3,color='purple')
# ax.set_ylabel('Mean Discharge')
# ax.set_xlabel('Months')
# ax.grid(zorder=0,linestyle='dotted', color='black')
# ax.get_figure().savefig(f"vis/vis{7}.png",bbox_inches='tight')

# %% [markdown]
# ax = chart[name.iloc[8]].plot(kind='bar',figsize=(4,3),zorder=3,color='purple')
# ax.set_ylabel('Mean Discharge')
# ax.set_xlabel('Months')
# ax.grid(zorder=0,linestyle='dotted', color='black')
# ax.get_figure().savefig(f"vis/vis{8}.png",bbox_inches='tight')

# %% [markdown]
# ax = chart[name.iloc[9]].plot(kind='bar',figsize=(4,3),zorder=3,color='purple')
# ax.set_ylabel('Mean Discharge')
# ax.set_xlabel('Months')
# ax.grid(zorder=0,linestyle='dotted', color='black')
# ax.get_figure().savefig(f"vis/vis{9}.png",bbox_inches='tight')

# %% [markdown]
# ax = chart[name.iloc[10]].plot(kind='bar',figsize=(4,3),zorder=3,color='purple')
# ax.set_ylabel('Mean Discharge')
# ax.set_xlabel('Months')
# ax.grid(zorder=0,linestyle='dotted', color='black')
# ax.get_figure().savefig(f"vis/vis{10}.png",bbox_inches='tight')

# %% [markdown]
# ax = chart[name.iloc[11]].plot(kind='bar',figsize=(4,3),zorder=3,color='purple')
# ax.set_ylabel('Mean Discharge')
# ax.set_xlabel('Months')
# ax.grid(zorder=0,linestyle='dotted', color='black')
# ax.get_figure().savefig(f"vis/vis{11}.png",bbox_inches='tight')

# %% [markdown]
# ax = chart[name.iloc[12]].plot(kind='bar',figsize=(4,3),zorder=3,color='purple')
# ax.set_ylabel('Mean Discharge')
# ax.set_xlabel('Months')
# ax.grid(zorder=0,linestyle='dotted', color='black')
# ax.get_figure().savefig(f"vis/vis{12}.png",bbox_inches='tight')

# %% [markdown]
# ax = chart[name.iloc[13]].plot(kind='bar',figsize=(4,3),zorder=3,color='purple')
# ax.set_ylabel('Mean Discharge')
# ax.set_xlabel('Months')
# ax.grid(zorder=0,linestyle='dotted', color='black')
# ax.get_figure().savefig(f"vis/vis{13}.png",bbox_inches='tight')

# %% [markdown]
# ax = chart[name.iloc[14]].plot(kind='bar',figsize=(4,3),zorder=3,color='purple')
# ax.set_ylabel('Mean Discharge')
# ax.set_xlabel('Months')
# ax.grid(zorder=0,linestyle='dotted', color='black')
# ax.get_figure().savefig(f"vis/vis{14}.png",bbox_inches='tight')

# %% [markdown]
# ax = chart[name.iloc[15]].plot(kind='bar',figsize=(4,3),zorder=3,color='purple')
# ax.set_ylabel('Mean Discharge')
# ax.set_xlabel('Months')
# ax.grid(zorder=0,linestyle='dotted', color='black')
# ax.get_figure().savefig(f"vis/vis{15}.png",bbox_inches='tight')

# %% [markdown]
# ax = chart[name.iloc[16]].plot(kind='bar',figsize=(4,3),zorder=3,color='purple')
# ax.set_ylabel('Mean Discharge')
# ax.set_xlabel('Months')
# ax.grid(zorder=0,linestyle='dotted', color='black')
# ax.get_figure().savefig(f"vis/vis{16}.png",bbox_inches='tight')

# %% [markdown]
# ax = chart[name.iloc[17]].plot(kind='bar',figsize=(4,3),zorder=3,color='purple')
# ax.set_ylabel('Mean Discharge')
# ax.set_xlabel('Months')
# ax.grid(zorder=0,linestyle='dotted', color='black')
# ax.get_figure().savefig(f"vis/vis{17}.png",bbox_inches='tight')

# %% [markdown]
# ax = chart[name.iloc[18]].plot(kind='bar',figsize=(4,3),zorder=3,color='purple')
# ax.set_ylabel('Mean Discharge')
# ax.set_xlabel('Months')
# ax.grid(zorder=0,linestyle='dotted', color='black')
# ax.get_figure().savefig(f"vis/vis{18}.png",bbox_inches='tight')

# %% [markdown]
# ax = chart[name.iloc[19]].plot(kind='bar',figsize=(4,3),zorder=3,color='purple')
# ax.set_ylabel('Mean Discharge')
# ax.set_xlabel('Months')
# ax.grid(zorder=0,linestyle='dotted', color='black')
# ax.get_figure().savefig(f"vis/vis{19}.png",bbox_inches='tight')

# %% [markdown]
# _Above code creates  vis{i} in vis but I already created them so, I mark this line of code_

# %% [markdown]
# ### Markers shows Png on charts

# %%
len(north)
# Out:
# 20

# %%
for i in range(len(north)):
    names = name.iloc[i]
    elv = elevation.iloc[i]
    are = area.iloc[i]
    marker = folium.Marker(
       location=[north.iloc[i],east.iloc[i]],
       tooltip= name.iloc[i],
       icon=folium.Icon(icon="cloud", color ='black'),
       popup=f"<div><p>Staion Name:{names}</p></div><b><img src=vis/vis{i}.png></b><div><p>Elevation:{elv} meters</p><div><div><p>Area:{are}km²</p><div>"
)
    marker.add_to(my_map)

# %%
for i in range(len(north)):
    names = name.iloc[i]
    elv = elevation.iloc[i]
    are = area.iloc[i]
    marker = folium.Marker(
       location=[north.iloc[i],east.iloc[i]],
       tooltip= name.iloc[i],
       icon=folium.Icon(icon="cloud", color ='darkgreen'),
       popup=f"<div><p>Staion Name:{names}</p></div><b><img src=https://raw.githubusercontent.com/Talenda/Antalya_Map/main/Antalya_HTML/vis/vis{i}.png></b><div><p>Elevation:{elv} meters</p><div><div><p>Area:{are}km²</p><div>"
)
    marker.add_to(my_map)

# %% [markdown]
# _F string formating for markers_

# %%
for i in range(len(north)):
    marker = folium.Marker(
    location=[north.iloc[i],east.iloc[i]],
       tooltip= name.iloc[i],
       icon=folium.Icon(icon="cloud", color ='darkblue'),
       popup="<div><p>Staion Name:{}</p><div><b><img src=https://raw.githubusercontent.com/Talenda/Antalya_Map/main/Antalya_HTML/vis/vis{}.png><div><p>Elevation:{} meters</p><div></p><div><div><p>Area:{} km²</p><div></b> ".format(name.iloc[i],i,elevation.iloc[i],area.iloc[i])
)
    marker.add_to(my_map)

# %% [markdown]
# _In string formating method I take graphfs from my github directly_

# %% [markdown]
# _I marked markers with 2 different string formatting method_
# **1 of them is enough**

# %%
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# my_map.save('Antalya_map.html')

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # Document

# %%
from IPython.display import IFrame
documentation = IFrame(src='https://python-visualization.github.io/folium/', width=1000, height=500)
display(documentation)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="https://python-visualization.github.io/folium/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import folium
from folium import plugins
import ipywidgets
import numpy as np
import pandas as pd

# %%
import geocoder
import geopy

# %% [markdown]
# import geocoder
# import geopy
# from vega_datasets import data as vds

# %%
#conda install -c conda-forge geocoder

# %%
#conda install -c conda-forge geopy

# %% [markdown]
# boulder_coords = [36.884804, 30.704044]
# my_map = folium.Map(location = boulder_coords, zoom_start =8 ,control_scale=True)

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # ipywidgets

# %%
# show map types using ipywidgets

# widget
select_widget=ipywidgets.Select(
    options=['Open Street Map', 'Terrain', 'Toner', 'Watercolor', 'Positron', 'Dark Matter'],
    value='Open Street Map',
    description='Map Type:',
    disabled=False)

# widget function
def select(map_type):
    if map_type == 'Open Street Map':
        display(folium.Map(location=boulder_coords, zoom_start=8,))
    if map_type == 'Terrain':
        display(folium.Map(location=boulder_coords, tiles='Stamen Terrain', zoom_start=8,))
    if map_type == 'Toner':
        display(folium.Map(location=boulder_coords, tiles='Stamen Toner', zoom_start=8,))
    if map_type == 'Watercolor':
        display(folium.Map(location=boulder_coords, tiles='Stamen Watercolor', zoom_start=8,))
    if map_type == 'Positron':
        display(folium.Map(location=boulder_coords, tiles='CartoDB Positron', zoom_start=8,))
    if map_type == 'Dark Matter':
        display(folium.Map(location=boulder_coords, tiles='CartoDB Dark_Matter', zoom_start=8,))
        
# interaction between widgets and function    
ipywidgets.interact(select, map_type=select_widget)
# Out:
# interactive(children=(Select(description='Map Type:', options=('Open Street Map', 'Terrain', 'Toner', 'Waterco…
# <function __main__.select(map_type)>

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # Map Markers

# %%
for i in range(len(north)):
    marker = folium.Marker(
    location=[north.iloc[i],east.iloc[i]],
       tooltip= name.iloc[i],
       icon=folium.Icon(icon="cloud", color ='darkblue'),
       popup="<div><p>Staion Name:{}</p><div><b><img src=https://raw.githubusercontent.com/Talenda/Antalya_Map/main/Antalya_HTML/vis/vis{}.png><div><p>Elevation:{} meters</p><div></p><div><div><p>Area:{} km²</p><div></b> ".format(name.iloc[i],i,elevation.iloc[i],area.iloc[i])
)
    marker.add_to(my_map)

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # Layer Control with map types

# %%
# show map types using layer control

# map
map_layer_control = folium.Map(location=boulder_coords, zoom_start=8)

# add tiles to map
folium.raster_layers.TileLayer('Open Street Map').add_to(my_map)
folium.raster_layers.TileLayer('Stamen Terrain').add_to(my_map)
folium.raster_layers.TileLayer('Stamen Toner').add_to(my_map)
folium.raster_layers.TileLayer('Stamen Watercolor').add_to(my_map)
folium.raster_layers.TileLayer('CartoDB Positron').add_to(my_map)
folium.raster_layers.TileLayer('CartoDB Dark_Matter').add_to(my_map)

# add layer control to show different maps
folium.LayerControl().add_to(my_map)

# display map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # Lat Long plugin

# %%
my_map.add_child(folium.LatLngPopup())
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # Plugins (minimap, zoom toggler, full screen)

# %%
# mini map, scroll zoom toggle button, full screen

# plugin for mini map
minimap = plugins.MiniMap(toggle_display=True)

# add minimap to map
my_map.add_child(minimap)

# add scroll zoom toggler to map
#plugins.ScrollZoomToggler().add_to(my_map)

# add full screen button to map
plugins.Fullscreen(position='topright').add_to(my_map)

# display map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # Measure Plugin

# %%
# measure control
measure_control = plugins.MeasureControl(position='topleft', 
                                         active_color='red', 
                                         completed_color='red', 
                                         primary_length_unit='kilometers')
# add measure control to map
my_map.add_child(measure_control)
# display map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# my_map.save('Antalya_measure.html')

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # Draw Plugin

# %%
# draw tools
# export=True exports the drawn shapes as a geojson file
draw = plugins.Draw(export=True)

# add draw tools to map
draw.add_to(my_map)

# display map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# draw = plugins.Draw(
#     export=True,
#     filename='my_data.geojson',
#     position='topleft',
#     draw_options={'polyline': {'allowIntersection': False}},
#     edit_options={'poly': {'allowIntersection': False}}
# ).add_to(my_map)
#
# my_map

# %% [markdown]
# my_map.save('Antalya.Draw.html')

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # Marker Shows Name of Station

# %%
from folium.features import DivIcon
import folium

# %%
for i in range(len(north)):
    marker = folium.Marker(
    location=[north.iloc[i],east.iloc[i]],
    icon=DivIcon(
        icon_size=(250,36),
        icon_anchor=(0,0),
        html='<div style="font-size: 10pt">{}</div>'.format(name.iloc[i])
        )
    ).add_to(my_map)

# %%
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# my_map.save('Antalya_stname.html')

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # Font Awesome and glyphicon bootstrap Markers

# %%
# search for 'font awesome' icons to see examples

# map
#boulder_coords = [36.884804, 30.704044]
#my_map = folium.Map(location = boulder_coords, zoom_start =8 ,control_scale=True)

for i in range(len(north)):
    marker = folium.Marker(
    location=[north.iloc[i],east.iloc[i]],
       tooltip= name.iloc[i],
       icon=folium.Icon(color='lightblue', icon='bolt', prefix='fa'),
       popup="<div><p>Staion Name:{}</p><div><b><img src=https://raw.githubusercontent.com/Talenda/Antalya_Map/main/Antalya_HTML/vis/vis{}.png><div><p>Elevation:{} meters</p><div></p><div><div><p>Area:{} km²</p><div></b> ".format(name.iloc[i],i,elevation.iloc[i],area.iloc[i])
)
    marker.add_to(my_map)

# display map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# my_map.save('Bolt.html')

# %%
# search for 'glyphicon bootstrap' icons to see examples

# map
#boulder_coords = [36.884804, 30.704044]
#my_map = folium.Map(location = boulder_coords, zoom_start =8 ,control_scale=True)

for i in range(len(north)):
    marker = folium.Marker(
    location=[north.iloc[i],east.iloc[i]],
       tooltip= name.iloc[i],
       icon=folium.Icon(icon='glyphicon-send', prefix='glyphicon',color='darkblue'),
       popup="<div><p>Staion Name:{}</p><div><b><img src=https://raw.githubusercontent.com/Talenda/Antalya_Map/main/Antalya_HTML/vis/vis{}.png><div><p>Elevation:{} meters</p><div></p><div><div><p>Area:{} km²</p><div></b> ".format(name.iloc[i],i,elevation.iloc[i],area.iloc[i])
)
    marker.add_to(my_map)

# display map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# import webbrowser
# webbrowser.open('https://getbootstrap.com/docs/3.3/components/')
# webbrowser.open('https://fontawesome.com/search?favorites=staff&s=solid')

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# # Dual Map

# %%
# dual map
my_dual = plugins.DualMap(location=boulder_coords, tiles=None, zoom_start=8,control_scale=True)

# map tiles
folium.TileLayer('Stamen Terrain').add_to(my_dual)
folium.TileLayer('CartoDB Positron').add_to(my_dual)

# add layer control to maps
folium.LayerControl().add_to(my_dual)

# display map(s)
my_dual
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# # Create a figure and Add map into it [change map size]
#
# from branca.element import Figure
#
# fig = Figure(width=500, height=300)
# fig.add_child(my_map)
# fig

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# # Search Plugin

# %% [markdown]
# import folium
# from folium import plugins
# import pandas as pd
# from folium.plugins import MarkerCluster
# from folium.plugins import Search

# %% [markdown]
# marker_cluster = MarkerCluster()
#
# for i in range(len(north)):
#     marker = folium.Marker(
#     location=[north.iloc[i],east.iloc[i]],
#     tooltip= name.iloc[i],
#     icon=folium.Icon(icon="cloud", color ='darkblue'),
#     popup="<div><p>Staion Name:{}</p><div><b><img  src=https://raw.githubusercontent.com/Talenda/Antalya_Map/main/Antalya_HTML/vis/vis{}.png><div><p>Elevation:{} meters</p><div></p><div><div><p>Area:{} km²</p><div></b> ".format(name.iloc[i],i,elevation.iloc[i],area.iloc[i])
# )
#     marker.add_to(marker_cluster)
#
# marker_cluster.add_to(my_map)

# %% [markdown]
# search =plugins.Search(layer=marker_cluster, position='topright', geom_type="Point",collapsed=False,search_zoom=8, placeholder='StationName').add_to(my_map)

# %% [markdown]
# plugins.Search(layer = marker_cluster)
# my_map.add_child(my_map)

# %% [markdown]
# my_map

# %% [markdown]
# marker=MarkerCluster().add_to(my_map)
# statesearch = Search(
#     layer=marker,
#     geom_type="Point",
#     placeholder="Search for station",
#     collapsed=False,
#     search_label="name",
#     weight=3,
# ).add_to(my_map)
#
# my_map

# %% [markdown]
# def visualize_locations_with_marker_cluster(df, zoom=4):
#     f = folium.Figure(width=1000, height=500)
#
#     center_lat=34.686567
#     center_lon=135.52000
#
#     m = folium.Map([center_lat,center_lon], zoom_start=4).add_to(f)
#     marker_cluster = MarkerCluster().add_to(my_map)
#
#     for i in range(len(north)):
#         marker = folium.Marker(
#         location=[north.iloc[i],east.iloc[i]],
#         tooltip= name.iloc[i],
#         icon=folium.Icon(icon="cloud", color ='darkblue'),
#         popup="<div><p>Staion Name:{}</p><div><b><img       src=https://raw.githubusercontent.com/Talenda/Antalya_Map/main/Antalya_HTML/vis/vis{}.png><div><p>Elevation:{} meters</p><div></p><div><div><p>Area:{} km²</p><div></b> ".format(name.iloc[i],i,elevation.iloc[i],area.iloc[i])
# )
#     marker.add_to(marker_cluster)
#
#     servicesearch = Search(
#         layer=marker_cluster,
#         search_label="tooltip",
#         placeholder='Search for a service',
#         collapsed=False,
#     ).add_to(my_map)
#     return my_map
# my_map

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# # Take Coordinates and Draw polygon

# %%
poly=[[30.997925,37.772886],[30.72876,37.455238],[30.951233,36.985003],[31.330261,36.952087],[31.681824,37.446516],[31.264343,37.883525],[30.997925,37.772886]]

# %%
def merge(poly):
    for i in poly:
        i[0],i[1] = i[1],i[0]
        i = tuple(i)
merge(poly)

# %% [markdown]
# lat=[]
# long=[]
# for i in range(len(poly)):
#     lat.append(poly[i][1])
#     long.append(poly[i][0])
#
# def merge(lat, long):
#     merged_list = [(lat[i], long[i]) for i in range(0, len(lat))]
#     return merged_list
#
# print(merge(lat,long))

# %%
folium.PolyLine(poly).add_to(my_map) 

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
from folium import plugins
plugins.AntPath(poly,color='red',fill='red').add_to(my_map)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# # Draw Roads

# %%
latlong=[[north.iloc[0],east.iloc[0]],[north.iloc[1],east.iloc[1]],[north.iloc[2],east.iloc[2]],[north.iloc[3],east.iloc[3]],[north.iloc[4],east.iloc[4]],[north.iloc[5],east.iloc[5]],[north.iloc[6],east.iloc[6]],[north.iloc[7],east.iloc[7]],[north.iloc[8],east.iloc[8]],[north.iloc[9],east.iloc[9]],[north.iloc[10],east.iloc[10]],[north.iloc[11],east.iloc[11]],[north.iloc[12],east.iloc[12]],[north.iloc[13],east.iloc[13]],[north.iloc[14],east.iloc[14]],[north.iloc[15],east.iloc[15]],[north.iloc[16],east.iloc[16]],[north.iloc[17],east.iloc[17]],[north.iloc[18],east.iloc[18]],[north.iloc[19],east.iloc[19]]]

# %%
folium.PolyLine(latlong).add_to(my_map)
    
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# ant path route
from folium import plugins
plugins.AntPath(latlong).add_to(my_map)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# # Geojson import

# %%
#Geojson
import webbrowser
#webbrowser.open('https://geojson.io/#map=7/36.390/29.756')

# %% [markdown]
# # add geojson file to map
# #folium.GeoJson('map.geojson', name='WorkArea').add_to(my_map)
#
# #add layer control to map (allows layer to be turned on or off)
# #folium.LayerControl(collapsed = False).add_to(my_map)
#
# # display map
# my_map

# %%
import webbrowser
#webbrowser.open('https://www.ocearch.org/tracker/')
